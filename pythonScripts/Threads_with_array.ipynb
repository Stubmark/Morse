# %%
# %reload_ext autoreload
# %autoreload 2
#%reload_ext autoreload 
import numpy as np
import math
import cmath
from scipy.fft import fft, ifft
import time
import threading, queue
#import Mod_getter 
#import nbimporter
import ClassMod

#from ClassMod import class1

pc1= ClassMod.class1()
Q=14
print("pc1.Q=",pc1.Q, "Q=",Q)

# img=np.zeros([100,500,3], dtype=np.uint8) 
# results = []

# def getter(q, queue_return):
#     global results
#     while True:
#      #   print("size of queue", q.qsize())
#         item = q.get()
#         print('getting item ...', item," size of queue:", q.qsize())
#         if item is None:
#             break
#         time.sleep(0.4)
#         results.append(42)
#         queue_return.put(results) # Send back results

# Main thread operation
def operation_on_main(q, speed):
    print("img:", ClassMod.img.shape)
    for i in range(10):
        time.sleep(speed)
        q.put(i)
    q.put(None) # send None to queue when done

if __name__ == '__main__':
 q1 = queue.Queue()
 q_return_data_1 = queue.Queue()
 queue_thread_slower = threading.Thread(target=ClassMod.getter, args=(q1,q_return_data_1))
 queue_thread_slower.daemon = True
 queue_thread_slower.start()

 q2 = queue.Queue()
 q_return_data_2 = queue.Queue()
 queue_thread_faster = threading.Thread(target=ClassMod.getter, args=(q2,q_return_data_2))
 queue_thread_faster.daemon = True
 queue_thread_faster.start()

 print("EXAMPLE : main thread - FASTER - than queue thread")
 operation_on_main(q1, 0.2)
 queue_thread_slower.join() # Wait for thread to finish
 print(q_return_data_1.get()) # Get results

 print("EXAMPLE : main thread - SLOWER - than queue thread")
 operation_on_main(q2, 0.6)
 queue_thread_faster.join() # Wait for thread to finish
 print(q_return_data_2.get()) # Get results
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# pc1.Q= 44 Q= 14
# EXAMPLE : main thread - FASTER - than queue thread
# img: (100, 500, 3)
# getting item ... 0  size of queue: 0
# getting item ... 1  size of queue: 1
# getting item ... 2  size of queue: 2
# getting item ... 3  size of queue: 3
# getting item ... 4  size of queue: 4
# getting item ... 5  size of queue: 5
# getting item ... 6  size of queue: 4
# getting item ... 7  size of queue: 3
# getting item ... 8  size of queue: 2
# getting item ... 9  size of queue: 1
# getting item ... None  size of queue: 0
# [441, 441, 441, 441, 441, 441, 441, 441, 441, 441]
# EXAMPLE : main thread - SLOWER - than queue thread
# img: (100, 500, 3)
# getting item ... 0  size of queue: 0
# getting item ... 1  size of queue: 0
# getting item ... 2  size of queue: 0
# getting item ... 3  size of queue: 0
# getting item ... 4  size of queue: 0
# getting item ... 5  size of queue: 0
# getting item ... 6  size of queue: 0
# getting item ... 7  size of queue: 0
# getting item ... 8  size of queue: 0
# getting item ... 9  size of queue: 1
# getting item ... None  size of queue: 0
# [441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441, 441]
